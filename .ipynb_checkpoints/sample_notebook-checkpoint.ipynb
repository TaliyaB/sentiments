# %%
"""
Tester Code
"""
from sentiments import TextProcessor, Visualizer, MachineLearning
import os

path = os.path.join(os.getcwd(), "sample_data/Student' s Perception towards Online Learning Questionnaire.csv")

#create data object
data = TextProcessor.TextProcessor()
data.parser(path=path)
print('Total respondents per course: {}'.format(data.dict_respondents_course))
print('Total number of respondents: {}'.format(data.int_respondents_count))
#print('Tokens per question {}'.format(data.list_tokens_per_question))
print('Number of responses for sentiment analysis: {}\nCorresponding tokens {}'.format(len(data.list_texts), len(data.list_tokens_per_text)))
print('Dataframe for sentiment analysis {}'.format(data.df_final_data_for_sentiment_analysis))

machine_learning_processes = MachineLearning.MachineLearning(df_for_sentiment_analysis=data.df_final_data_for_sentiment_analysis,
                                                             tokens_per_question=data.list_tokens_per_question,
                                                             respondents_by_course=data.dict_respondents_course,
                                                             respondents_by_block=data.dict_respondents_block,
                                                             total_respondents=data.int_respondents_count)
machine_learning_processes.exploratory_data_analysis(n_words=5)
machine_learning_processes.sentiment_analysis()
#print('Sentiment Analysis\n{}'.format(machine_learning_processes.df_sentiment_analysis_result))
#print('Positive Texts\n{}'.format(machine_learning_processes.df_positive_predicted_sentiments))
machine_learning_processes.LatentDirichletAllocation(
    tokens= machine_learning_processes.df_negative_predicted_sentiments['Tokens'].tolist(),
    filename_lda_model= 'all_generated\\negative.gensim',
    filename_corpus= 'all_generated\\negative_corpus.pkl',
    filename_dictionary= 'all_generated\\negative_dictionary.gensim'
)
machine_learning_processes.LatentDirichletAllocation(
    tokens=machine_learning_processes.df_positive_predicted_sentiments['Tokens'].tolist(),
    filename_lda_model = 'all_generated\\positive.gensim',
    filename_corpus= 'all_generated\\positive_corpus.pkl',
    filename_dictionary= 'all_generated\\positive_dictionary.gensim'
)
positive_wordCloud = Visualizer.Visualizer()
positive_wordCloud.wordCloud(text=machine_learning_processes.df_positive_predicted_sentiments['Text'].tolist(),
                             color='white', title='Positive WordCloud', output_file='all_generated\\positive_wordcloud.png')
negative_wordCloud = Visualizer.Visualizer()
negative_wordCloud.wordCloud(text=machine_learning_processes.df_negative_predicted_sentiments['Text'].tolist(),
                             color='black', title='Negative WordCloud', output_file='all_generated\\negative_wordcloud.png')
# Out:
# Total respondents per course: {'BSIT': 17, 'BSCS': 15}
# Total number of respondents: 32
# Number of responses for sentiment analysis: 224
# Corresponding tokens 224
# Dataframe for sentiment analysis                                                   Text  \
# 0    If we rate that from 1-10, I rate it 5. Not al...
# 1    Even if I have cellular network, wifi But at s...
# 2    For me it's average. Sometime I can cope up an...
# 3    At first, I found it difficult because we're s...
# 4    Using the Distance learning technologies is ea...
# ..                                                 ...
# 219  I believe distance education is not that bad, ...
# 220          Not that good, but still trying to adjust
# 221           i feel nothing about distance education.
# 222  I just think I'll be more and discover through...
# 223  It's good in terms of financial issues but in ...
#
#                                                 Tokens  Question Number
# 0    [rate, rate, 5, students, budget, gadget, orde...                1
# 1    [Even, cellular, network, wifi, point, connect...                1
# 2    [average, Sometime, cope, also, time, find, ha...                1
# 3    [first, found, difficult, still, process, adap...                1
# 4    [Using, Distance, learning, technologies, easy...                1
# ..                                                 ...              ...
# 219  [believe, distance, education, bad, country, w...                7
# 220                      [good, still, trying, adjust]                7
# 221               [feel, nothing, distance, education]                7
# 222  [think, discover, online, classes, one, thing,...                7
# 223  [good, terms, financial, issues, terms, learni...                7
#
# [224 rows x 3 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3396/1756272599.py in <module>
#      25 #print('Sentiment Analysis\n{}'.format(machine_learning_processes.df_sentiment_analysis_result))
#      26 #print('Positive Texts\n{}'.format(machine_learning_processes.df_positive_predicted_sentiments))
# ---> 27 machine_learning_processes.LatentDirichletAllocation(
#         global machine_learning_processes.LatentDirichletAllocation = <bound method MachineLearning.LatentDirichletAllocation of <sentiments.MachineLearning.MachineLearning object at 0x000001D3D2502820>>
#         global tokens = undefined
#         global machine_learning_processes.df_negative_predicted_sentiments.tolist = undefined
#         global filename_lda_model = undefined
#         global filename_corpus = undefined
#         global filename_dictionary = undefined
#      28     tokens= machine_learning_processes.df_negative_predicted_sentiments['Tokens'].tolist(),
#      29     filename_lda_model= 'all_generated\\negative.gensim',
#
# TypeError: LatentDirichletAllocation() got an unexpected keyword argument 'filename_lda_model'

# %%
'''
LDA of Negative responses
'''
import pyLDAvis
import gensim
import pickle
pyLDAvis.enable_notebook()
lda = 'all_generated\\negative.gensim'
dictionary = gensim.corpora.Dictionary.load('all_generated\\negative_dictionary.gensim')
corpus = pickle.load(open('all_generated\\negative_corpus.pkl', 'rb'))
lda_model = gensim.models.ldamodel.LdaModel.load(lda)
pyLDAvis.enable_notebook()
lda_display = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\clark\.conda\envs\sentiments\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el339620092926126569199902466"></div>
# <script type="text/javascript">
#
# var ldavis_el339620092926126569199902466_data = {"mdsDat": {"x": [-0.11556182467095011, 0.10194860979670577, -0.001862574421676321, -0.05137526919947902, 0.06685105849539966], "y": [0.017968089432687802, 0.07265676646253048, 0.07114004917403578, -0.047500651878849096, -0.11426425319040502], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [30.761515369292425, 24.555840978504424, 16.29014451146097, 14.515665222292359, 13.876833918449824]}, "tinfo": {"Term": ["stressful", "internet", "difficult", "access", "hard", "feel", "really", "Difficult", "connection", "environment", "always", "focus", "sometimes", "learning", "students", "need", "schoolworks", "face", "even", "like", "much", "year", "first", "Intermediate", "use", "say", "dont", "academic", "times", "already", "access", "quite", "different", "area", "Difficult", "country", "areas", "noise", "finish", "work", "place", "students", "task", "connect", "factors", "situation", "internet", "terms", "around", "hit", "admit", "Philippines", "conduct", "gadgets", "schools", "providing", "possessing", "local", "forced", "accomplish", "poor", "issues", "online", "affect", "education", "right", "connection", "schoolwork", "due", "hard", "since", "good", "time", "difficult", "focus", "distance", "easy", "learning", "use", "still", "way", "face", "feel", "simple", "always", "missed", "considering", "working", "trying", "like", "travel", "stopped", "interact", "point", "19", "everywhere", "close", "covid", "peoole", "alone", "unfortunately", "moments", "eyes", "screens", "masks", "hurt", "probably", "makes", "staring", "either", "social", "technology", "much", "adjust", "learning", "study", "times", "stress", "student", "Distance", "easy", "pandemic", "good", "even", "time", "schoolwork", "use", "difficult", "classes", "distance", "education", "online", "since", "intuitive", "Hard", "matters", "performance", "devices", "PC", "CP", "Edmodo", "based", "lack", "experience", "Noise", "Responsibilities", "stuff", "home", "background", "focusing", "traditional", "took", "Much", "course", "laptop", "yet", "baranggay", "6", "consistent", "ten", "One", "highest", "barriers", "environment", "stable", "family", "connectivity", "academic", "rate", "activities", "connection", "internet", "distance", "use", "applications", "learning", "difficult", "time", "poor", "connect", "find", "computer", "much", "problem", "lot", "needed", "harder", "7", "learn", "really", "dont", "schoolworks", "need", "downloaded", "although", "topics", "discussion", "encounter", "ISP", "cope", "Based", "willing", "live", "agree", "strong", "means", "give", "approach", "crisis", "brought", "expertise", "signal", "wifi", "mastering", "lazy", "insane", "seriously", "driving", "person", "difficult", "understand", "unstable", "hard", "sometimes", "get", "focus", "time", "learn", "internet", "connection", "since", "stressful", "still", "much", "Difficult", "little", "sad", "fast", "way", "interruptions", "power", "accessing", "cause", "Sometimes", "actually", "stressful", "year", "first", "Intermediate", "expense", "along", "accounted", "worry", "renting", "traveling", "factor", "dorm", "stressed", "managing", "personal", "handle", "becuause", "connections", "undrestand", "second", "Yes", "1", "gon", "na", "adapted", "surrounding", "check", "look", "everyday", "Stress", "say", "already", "affected", "environment", "even", "hard", "also", "school", "sometimes", "students", "since", "focus", "times", "academic", "distance", "much", "learning", "time", "sad", "ca", "would", "think", "problems", "stay", "many", "poor"], "Freq": [9.0, 21.0, 18.0, 8.0, 11.0, 7.0, 3.0, 9.0, 11.0, 3.0, 4.0, 5.0, 5.0, 11.0, 5.0, 3.0, 3.0, 3.0, 3.0, 4.0, 6.0, 1.0, 1.0, 1.0, 6.0, 2.0, 1.0, 2.0, 6.0, 2.0, 7.647396844113737, 3.088150041645309, 2.4025698630498065, 2.3910223290266046, 7.659291185889821, 1.652034433317229, 1.6520301016044685, 1.65202008451871, 1.6518947355807048, 1.6294130109879756, 3.154307207707383, 3.9054646443191556, 2.4031565393 ...

# %%
'''
LDA of Positive responses
'''
import pyLDAvis
import gensim
import pickle
pyLDAvis.enable_notebook()
lda = 'all_generated\\positive.gensim'
dictionary = gensim.corpora.Dictionary.load('all_generated\\positive_dictionary.gensim')
corpus = pickle.load(open('all_generated\\positive_corpus.pkl', 'rb'))
lda_model = gensim.models.ldamodel.LdaModel.load(lda)
pyLDAvis.enable_notebook()
lda_display = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\clark\.conda\envs\sentiments\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el339620092926140006449031546"></div>
# <script type="text/javascript">
#
# var ldavis_el339620092926140006449031546_data = {"mdsDat": {"x": [0.011739711480752648, -0.08429985890973356, 0.10456555922042732, -0.08983114264528279, 0.057825730853836334], "y": [0.045775506606759345, 0.07469435974269639, -0.053813844246341946, -0.10321795590942262, 0.03656193380630877], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [29.021470586821536, 22.59018751100741, 19.609008520964665, 14.499123055887072, 14.280210325319311]}, "tinfo": {"Term": ["important", "difficult", "easy", "online", "gadgets", "lessons", "understand", "face", "depends", "Easy", "works", "internet", "student", "better", "use", "household", "first", "learn", "study", "learning", "also", "education", "focus", "school", "need", "time", "questions", "put", "schoolwork", "schoolworks", "environment", "rate", "process", "health", "responsibilities", "honest", "implement", "could", "face", "learning", "able", "good", "familiarize", "cellphone", "passed", "hesitations", "kinds", "found", "technologies", "adapting", "etc", "survive", "facing", "goes", "finished", "getting", "method", "struggles", "controlled", "successfully", "situation", "new", "really", "different", "place", "distance", "way", "much", "especially", "knowledge", "since", "time", "connection", "using", "hard", "easy", "stressful", "important", "like", "internet", "focused", "difficult", "find", "us", "think", "may", "sacrifice", "long", "relatives", "include", "distractions", "need", "schoolworks", "chose", "deadline", "midnight", "sleep", "answer", "remaining", "submit", "screen", "gave", "f2f", "polangui", "sense", "far", "rather", "quite", "prepared", "bu", "Especially", "SHS", "human", "course", "rent", "education", "manage", "activities", "due", "home", "order", "time", "classes", "online", "focused", "internet", "stay", "since", "us", "learning", "school", "also", "connection", "hard", "easy", "much", "wifi", "better", "questions", "Easy", "dont", "experience", "weak", "learn", "online", "harder", "night", "Since", "Well", "right", "Finding", "daily", "besides", "explain", "response", "quicker", "stable", "clarifications", "ever", "instant", "queries", "needed", "shoolworks", "difficulties", "F2f", "feedback", "receive", "study", "important", "ask", "Im", "helps", "know", "communication", "still", "cope", "internet", "way", "understand", "lessons", "like", "connection", "hard", "since", "wifi", "much", "thing", "understanding", "one", "depends", "works", "given", "connected", "finishing", "chores", "household", "first", "sitting", "straight", "ca", "near", "located", "speaking", "performance", "speed", "reference", "prof", "module", "moved", "synchronous", "asynchronous", "type", "optic", "fiber", "individual", "unreliable", "cable", "slow", "fine", "difficult", "focus", "average", "also", "easy", "school", "internet", "schoolwork", "understanding", "focused", "since", "fairly", "intermittent", "sometimes", "stay", "schoolworks", "stressful", "know", "pandemic", "year", "topic", "working", "gadgets", "professor", "Yes", "lessons", "understand", "intervention", "means", "absorbing", "acquiring", "set", "terms", "communicate", "question", "major", "hesitation", "properly", "complete", "browse", "suitable", "comply", "requirements", "learned", "active", "event", "Always", "side", "luck", "yeah", "emotion", "disadvantages", "put", "use", "student", "every", "students", "best", "easy", "important", "education", "without", "time", "communication", "hard", "face", "difficult", "easily", "ask", "gain", "find", "think", "technology", "stressful", "essential", "knows", "using"], "Freq": [15.0, 9.0, 15.0, 6.0, 3.0, 4.0, 4.0, 9.0, 3.0, 4.0, 3.0, 13.0, 5.0, 3.0, 5.0, 3.0, 3.0, 3.0, 4.0, 11.0, 4.0, 3.0, 3.0, 4.0, 4.0, 11.0, 2.0, 2.0, 3.0, 3.0, 3.0507936043573367, 2.3246905115257106, 1.5982088325846777, 1.5982041328950438, 1.5981982582830012, 1.5981750209286998, 1.5976983940716494, 1.597167720783808, 6.6878761014974035, 7.415667949470854, 2.3250933793648936, 2.3249145300649325, 0. ...
